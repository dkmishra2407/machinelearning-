# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Desktop/madfhantr.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,:12]

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
y=df['Loan_Status']

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
a={'Y':1,'N':0}
z=df.Loan_Status.map(a)

# %%
z
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
fig = px.histogram(df,x='ApplicantIncome',nbins=47)
fig.update_layout(bargap=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
tree = DecisionTreeClassifier(random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,z,test_size=0.25)

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
values = {'Yes':1,'No':0}
df['Married'] = df.Married.map(values)

# %%
values = {'Male':1,'Female':0}
df['Gender'] = df.Gender.map(values)

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
values = {'1':1,'2':2,'3+':3,'0':0}
df['Dependents'] = df.Dependents.map(values)

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents     Education Self_Employed  \
# 0    LP001002     1.0      0.0         0.0      Graduate            No
# 1    LP001003     1.0      1.0         1.0      Graduate            No
# 2    LP001005     1.0      1.0         0.0      Graduate           Yes
# 3    LP001006     1.0      1.0         0.0  Not Graduate            No
# 4    LP001008     1.0      0.0         0.0      Graduate            No
# ..        ...     ...      ...         ...           ...           ...
# 609  LP002978     0.0      0.0         0.0      Graduate            No
# 610  LP002979     1.0      1.0         3.0      Graduate            No
# 611  LP002983     1.0      1.0         1.0      Graduate            No
# 612  LP002984     1.0      1.0         2.0      Graduate            No
# 613  LP002990     0.0      0.0         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
values = {'Graduate':1,'Not Graduate':0}
df['Education'] = df.Education.map(values)

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education Self_Employed  \
# 0    LP001002     1.0      0.0         0.0          1            No
# 1    LP001003     1.0      1.0         1.0          1            No
# 2    LP001005     1.0      1.0         0.0          1           Yes
# 3    LP001006     1.0      1.0         0.0          0            No
# 4    LP001008     1.0      0.0         0.0          1            No
# ..        ...     ...      ...         ...        ...           ...
# 609  LP002978     0.0      0.0         0.0          1            No
# 610  LP002979     1.0      1.0         3.0          1            No
# 611  LP002983     1.0      1.0         1.0          1            No
# 612  LP002984     1.0      1.0         2.0          1            No
# 613  LP002990     0.0      0.0         0.0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# %%
df[['LoanAmount','Loan_Amount_Term','Credit_History']] = imputer.fit_transform(df[['LoanAmount','Loan_Amount_Term','Credit_History']])

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
df[['Dependents','Self_Employed','Married','Gender']] = imputer.fit_transform(df[['Dependents','Self_Employed','Married','Gender']])

# %%
df
# Out:
#       Loan_ID Gender Married Dependents  Education Self_Employed  \
# 0    LP001002    1.0     0.0        0.0          1            No
# 1    LP001003    1.0     1.0        1.0          1            No
# 2    LP001005    1.0     1.0        0.0          1           Yes
# 3    LP001006    1.0     1.0        0.0          0            No
# 4    LP001008    1.0     0.0        0.0          1            No
# ..        ...    ...     ...        ...        ...           ...
# 609  LP002978    0.0     0.0        0.0          1            No
# 610  LP002979    1.0     1.0        3.0          1            No
# 611  LP002983    1.0     1.0        1.0          1            No
# 612  LP002984    1.0     1.0        2.0          1            No
# 613  LP002990    0.0     0.0        0.0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education              int64
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df
# Out:
#       Loan_ID Gender Married Dependents  Education Self_Employed  \
# 0    LP001002    1.0     0.0        0.0          1            No
# 1    LP001003    1.0     1.0        1.0          1            No
# 2    LP001005    1.0     1.0        0.0          1           Yes
# 3    LP001006    1.0     1.0        0.0          0            No
# 4    LP001008    1.0     0.0        0.0          1            No
# ..        ...    ...     ...        ...        ...           ...
# 609  LP002978    0.0     0.0        0.0          1            No
# 610  LP002979    1.0     1.0        3.0          1            No
# 611  LP002983    1.0     1.0        1.0          1            No
# 612  LP002984    1.0     1.0        2.0          1            No
# 613  LP002990    0.0     0.0        0.0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#       Loan_ID Gender Married Dependents  Education Self_Employed  \
# 0    LP001002    1.0     0.0        0.0          1            No
# 1    LP001003    1.0     1.0        1.0          1            No
# 2    LP001005    1.0     1.0        0.0          1           Yes
# 3    LP001006    1.0     1.0        0.0          0            No
# 4    LP001008    1.0     0.0        0.0          1            No
# ..        ...    ...     ...        ...        ...           ...
# 609  LP002978    0.0     0.0        0.0          1            No
# 610  LP002979    1.0     1.0        3.0          1            No
# 611  LP002983    1.0     1.0        1.0          1            No
# 612  LP002984    1.0     1.0        2.0          1            No
# 613  LP002990    0.0     0.0        0.0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['Gender','Married','Education','Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History']],z,test_size=0.25)

# %%
x_train
# Out:
#     Gender  Education  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 378    1.0          1             3069                0.0   71.000000
# 506    1.0          1            20833             6667.0  480.000000
# 322    1.0          0             3601             1590.0  146.412162
# 286    0.0          1             2600             1717.0   99.000000
# 109    1.0          0             2071              754.0   94.000000
# ..     ...        ...              ...                ...         ...
# 146    0.0          1            14866                0.0   70.000000
# 191    1.0          1            12000                0.0  164.000000
# 593    1.0          1             3859             3300.0  142.000000
# 365    1.0          0             6216                0.0  133.000000
# 458    1.0          1             4354                0.0  136.000000
#
#      Loan_Amount_Term  Credit_History
# 378             480.0        1.000000
# 506             360.0        0.842199
# ...

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
pre = tree.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(pre,y_test)
# Out:
# 0.7077922077922078
