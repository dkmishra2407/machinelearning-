# %%
import pandas as pd
import numpy as np 

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %%
reg = LinearRegression()

# %%
df = pd.read_csv('../LP-1 Dataset/Regression/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
x = df[['Glucose']]
y = df['Outcome']

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.25)

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([ 0.18668729,  0.28479898,  0.25676707,  0.24975909,  0.45299043,
#         0.22172718, -0.00252809,  0.31983886,  0.57913402,  0.53007818,
#         0.277791  ,  0.75433345,  0.53708615,  0.17267134,  0.11660752,
#         0.37590268,  0.08857561,  0.10259157,  0.78236535,  0.48102234,
#         0.22873516,  0.11660752,  0.24275111,  0.17267134,  0.40393459,
#         0.78937333,  0.26377504,  0.20070325,  0.2147192 ,  0.1236155 ,
#         0.63519783,  0.5230702 ,  0.78937333,  0.67023772,  0.26377504,
#         0.56511806,  0.88047704,  0.26377504,  0.34787077,  0.41795054,
#         0.09558359,  0.44598245,  0.26377504,  0.22873516,  0.14463943,
#         0.60716593,  0.277791  ,  0.16566336,  0.28479898,  0.71228558,
#         0.15865539,  0.51606222,  0.48102234,  0.43897447,  0.47401436,
#         0.01849584,  0.60716593,  0.06054371,  0.34787077,  0.6772457 ,
#         0.57913402,  0.35487875,  0.40393459,  0.14463943,  0.08857561,
#         0.53007818,  0.06755168,  0.4599984 ,  0.22873516,  0.70527761,
#         0.55110211,  0.08156764,  0.13763145,  0.16566336,  0.22172718,
#         0.22172718,  0.23574314,  0.17267134,  0.31983886,  0.27078302,
#         0.6141739 ,  0.22873516,  0.02550382,  0.44598245,  0.33385482,
#         0.81039726,  0.56511806,  0.3688947 ,  0.19369527,  0.10959955,
#         0.15164741,  0.14463943,  0.01849584,  0.34086279,  0.36188672,
#         0.50905425,  0.24275111,  0.08156764,  0.74031749, -0.06559988,
#         0.64921379,  0.04652775,  0.38291066,  0.5230702 ,  0.60716593,
#         0.28479898,  0.48803031,  0.71228558,  0.06054371,  0.26377504,
#         0.17967932,  0.72630154,  0.23574314,  0.67023772,  0.28479898,
#         0.3688947 ,  0.63519783,  0.27078302,  0.13763145,  0.30582291,
#         0.23574314,  0.20070325,  0.33385482,  0.13062348,  0.55811009,
#         0.20771123,  0.30582291,  0.58614199,  0.44598245,  0.82441322,
#         0.78236535,  0.55811009,  0.26377504,  0.45299043,  0.7683494 ,
#         0.2147192 ,  0.34086279,  0.60716593,  0.55110211, -0.02355202,
#         0.28479898,  0.13062348,  0.47401436,  0.47401436,  0.15164741,
#         0.08857561,  0.09558359,  0.01148787,  0.28479898,  0.65622177,
#         0.03951977,  0.16566336,  0.5230702 ,  0.01849584,  0.08857561,
#         0.28479898,  0.47401436,  0.62818986,  0.43897447,  0.41094256,
#         0.42495852,  0.62818986,  0.25676707,  0.06054371,  0.10959955,
#         0.69826963,  0.11660752,  0.5230702 ,  0.83842917,  0.35487875,
#         0.6141739 ,  0.20070325,  0.36188672,  0.36188672,  0.58614199,
#         0.2147192 ,  0.37590268,  0.20070325,  0.22873516,  0.41795054,
#         0.51606222,  0.56511806,  0.20070325,  0.53007818,  0.39692661,
#         0.20070325,  0.06054371,  0.08857561,  0.8594531 ,  0.36188672,
#         0.04652775,  0.24275111])

# %%
reg.coef_
# Out:
# array([0.00700798])

# %%
reg.intercept_
# Out:
# -0.5000944681447548

# %%
r2_score(y_test, reg.predict(x_test))
# Out:
# 0.19893332863069635

# %%
mean_squared_error(y_test, reg.predict(x_test))
# Out:
# 0.18442526149932945

# %%
plt.title("Regresion")
plt.xlabel("Glucose")
plt.scatter(x_test,y_test)

plt.plot(x_test, reg.predict(x_test), color='red', linewidth=2, label='Regression line')
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,reg.predict(x_test))
# Out:
# 0.36483845796408704
