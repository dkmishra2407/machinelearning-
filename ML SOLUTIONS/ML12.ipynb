# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('./advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['TV'],df['Sales'])

# %%
x = df.iloc[:,:3]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['Sales']

# %%
from sklearn.linear_model import LinearRegression

regrex = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 169  284.3   10.6        6.4
# 68   237.4   27.5       11.0
# 65    69.0    9.3        0.9
# 193  166.8   42.0        3.6
# 24    62.3   12.6       18.3
# ..     ...    ...        ...
# 124  229.5   32.3       74.2
# 22    13.2   15.9       49.6
# 27   240.1   16.7       22.9
# 4    180.8   10.8       58.4
# 140   73.4   17.0       12.9
#
# [150 rows x 3 columns]

# %%
regrex.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = regrex.predict(x_test)

# %%
pred
# Out:
# array([ 9.38897839, 13.11755394, 20.02875733,  9.97595358, 13.88790466,
#        13.69368729, 17.17881311, 19.85515316, 21.41825135, 15.88886492,
#        19.22690646, 14.46292222,  8.57239241, 14.76099049, 22.94350554,
#         5.87244804, 16.69849199, 12.63736606, 24.41504669, 18.33565986,
#        23.94195507, 17.21850013,  7.5488194 , 20.8578826 , 10.91195386,
#         8.9514154 , 17.53142602, 11.55943112, 20.64916781,  9.38570718,
#         6.71623604, 24.20747995, 13.20751552, 16.84858242, 12.44586861,
#        21.69693337, 20.96837121, 17.25793264, 13.84290522, 21.28112054,
#        17.25991938, 19.15820241, 22.00049046, 20.69083049, 20.95060373,
#        12.80098992, 11.98480345, 11.59402657, 20.32767791, 20.89665627])

# %%
y_test
# Out:
# 130     1.6
# 157    10.1
# 15     22.4
# 166     8.0
# 116    12.2
# 63     14.0
# 122    16.6
# 178    16.8
# 109    19.8
# 9      15.6
# 62     20.7
# 77     14.2
# 132     5.7
# 177    16.7
# 61     24.2
# 108     5.3
# 95     16.9
# 135    11.6
# 98     25.4
# 113    20.9
# 198    25.5
# 174    16.5
# 106     7.2
# 102    19.8
# 125    10.6
# 44      8.5
# 110    18.4
# 51     10.7
# 84     21.7
# 158     7.3
# 155     3.2
# 183    26.2
# 83     13.6
# 162    19.9
# 73     11.0
# 188    20.9
# 69     22.3
# 154    20.6
# 159    12.9
# 104    20.7
# 165    16.9
# 53     21.2
# 47     23.2
# 0      22.1
# 28     18.9
# 90     14.0
# 88     12.9
# 190    10.8
# 55     23.7
# 35     17.8
# Name: Sales, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,accuracy_score,ConfusionMatrixDisplay
print('Mean Squared Error:', mean_squared_error(y_test, pred))
# Out:
# Mean Squared Error: 4.187133731023376

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, pred)

ConfusionMatrixDisplay(cm).plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
# ----> 3 cm = confusion_matrix(y_test, pred)
#       5 ConfusionMatrixDisplay(cm).plot()
#       6 plt.show()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:342, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     247 @validate_params(
#     248     {
#     249         "y_true": ["array-like"],
#    (...)
#     258     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     259 ):
#     260     """Compute confusion matrix to evaluate the accuracy of a classification.
#     261
#     262     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     340     (np.int64(0), np.int64(2), np.int64(1), np.int64(1))
#     341     """
# --> 342     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     343     if y_type not in ("binary", "multiclass"):
#     344         raise ValueError("%s is not supported" % y_type)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:123, in _check_targets(y_true, y_pred)
#     121 # No metrics support "multiclass-multioutput" format
#     122 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 123     raise ValueError("{0} is not supported".format(y_type))
#     125 if y_type in ["binary", "multiclass"]:
#     126     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous is not supported
