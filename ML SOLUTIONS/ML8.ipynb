# %%
import numpy as np 
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, classification_report, confusion_matrix  # noqa: E501

# %%
df = pd.read_csv('../LP-1 Dataset/K-Means & Hirarchical Clustering/50_Startups.csv')

# %%
df
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
import matplotlib.pyplot as plt

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df['STATE'].value_counts()
# Out:
# STATE
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
df[['STATE']] = label.fit(df[['STATE']])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %%
x1 = df.iloc[:,:4]
y1 = df['PROFIT']

# %%
x_train,x_test,y_train,y_test = train_test_split(x1, y1,test_size=0.1)

# %%
x_train
# Out:
#           RND      ADMIN        MKT           STATE
# 30   61994.48  115641.28   91131.24  LabelEncoder()
# 17   94657.16  145077.58  282574.31  LabelEncoder()
# 11  100671.96   91790.61  249744.55  LabelEncoder()
# 2   153441.51  101145.55  407934.54  LabelEncoder()
# 7   130298.13  145530.06  323876.68  LabelEncoder()
# 13   91992.39  135495.07  252664.93  LabelEncoder()
# 44   22177.74  154806.14   28334.72  LabelEncoder()
# 36   28663.76  127056.21  201126.82  LabelEncoder()
# 3   144372.41  118671.85  383199.62  LabelEncoder()
# 49       0.00  116983.80   45173.06  LabelEncoder()
# 0   165349.20  136897.80  471784.10  LabelEncoder()
# 6   134615.46  147198.87  127716.82  LabelEncoder()
# 10  101913.08  110594.11  229160.95  LabelEncoder()
# 28   66051.52  182645.56  118148.20  LabelEncoder()
# 9   123334.88  108679.17  304981.62  LabelEncoder()
# 23   67532.53  105751.03  304768.73  LabelEncoder()
# 22   73994.56  122782.75  303319.26  LabelEncoder()
# ...

# %%
df = pd.read_csv('../LP-1 Dataset/K-Means & Hirarchical Clustering/50_Startups.csv')

# %%
df['STATE'] = label.fit_transform(df[['STATE']])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df['STATE']
# Out:
# 0     2
# 1     0
# 2     1
# 3     2
# 4     1
# 5     2
# 6     0
# 7     1
# 8     2
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    1
# 15    2
# 16    0
# 17    2
# 18    1
# 19    2
# 20    0
# 21    2
# 22    1
# 23    1
# 24    2
# 25    0
# 26    1
# 27    2
# 28    1
# 29    2
# 30    1
# 31    2
# 32    0
# 33    1
# 34    0
# 35    2
# 36    1
# 37    0
# 38    2
# 39    0
# 40    0
# 41    1
# 42    0
# 43    2
# 44    0
# 45    2
# 46    1
# 47    0
# 48    2
# 49    0
# Name: STATE, dtype: int32

# %%
df.shape
# Out:
# (50, 5)

# %%
df.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE       int32
# PROFIT    float64
# dtype: object

# %%
df
# Out:
#           RND      ADMIN        MKT  STATE     PROFIT
# 0   165349.20  136897.80  471784.10      2  192261.83
# 1   162597.70  151377.59  443898.53      0  191792.06
# 2   153441.51  101145.55  407934.54      1  191050.39
# 3   144372.41  118671.85  383199.62      2  182901.99
# 4   142107.34   91391.77  366168.42      1  166187.94
# 5   131876.90   99814.71  362861.36      2  156991.12
# 6   134615.46  147198.87  127716.82      0  156122.51
# 7   130298.13  145530.06  323876.68      1  155752.60
# 8   120542.52  148718.95  311613.29      2  152211.77
# 9   123334.88  108679.17  304981.62      0  149759.96
# 10  101913.08  110594.11  229160.95      1  146121.95
# 11  100671.96   91790.61  249744.55      0  144259.40
# 12   93863.75  127320.38  249839.44      1  141585.52
# 13   91992.39  135495.07  252664.93      0  134307.35
# 14  119943.24  156547.42  256512.92      1  132602.65
# 15  114523.61  122616.84  261776.23      2  129917.04
# ...

# %%
x = df.iloc[:,:4]

# %%
x
# Out:
#           RND      ADMIN        MKT  STATE
# 0   165349.20  136897.80  471784.10      2
# 1   162597.70  151377.59  443898.53      0
# 2   153441.51  101145.55  407934.54      1
# 3   144372.41  118671.85  383199.62      2
# 4   142107.34   91391.77  366168.42      1
# 5   131876.90   99814.71  362861.36      2
# 6   134615.46  147198.87  127716.82      0
# 7   130298.13  145530.06  323876.68      1
# 8   120542.52  148718.95  311613.29      2
# 9   123334.88  108679.17  304981.62      0
# 10  101913.08  110594.11  229160.95      1
# 11  100671.96   91790.61  249744.55      0
# 12   93863.75  127320.38  249839.44      1
# 13   91992.39  135495.07  252664.93      0
# 14  119943.24  156547.42  256512.92      1
# 15  114523.61  122616.84  261776.23      2
# 16   78013.11  121597.55  264346.06      0
# 17   94657.16  145077.58  282574.31      2
# 18   91749.16  114175.79  294919.57      1
# 19   86419.70  153514.11       0.00      2
# 20   76253.86  113867.30  298664.47      0
# ...

# %%
y = df['PROFIT']

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
plt.scatter(x['MKT'],y)

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering

# %%
from sklearn.metrics import silhouette_score

# %%
sse = []
for i in range(1,16):
    km = KMeans(n_clusters=i)
    km.fit_predict(x)
    sse.append(km.inertia_)

# %%
sse
# Out:
# [874499791457.0032,
#  322956548760.0659,
#  212940052373.7172,
#  169033521062.19623,
#  94895987543.41779,
#  86199303999.6391,
#  70249035752.49992,
#  66792978389.00914,
#  57225331228.49936,
#  52336393054.29289,
#  46215256317.80861,
#  40354052916.19709,
#  39630973802.20127,
#  35263866993.48572,
#  31793102741.121544]

# %%
plt.grid()
plt.xticks(range(1,16))
plt.plot(range(1,16),sse,marker='o')

# %%
km = KMeans(n_clusters=5,random_state=42)

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.1)

# %%
x_train
# Out:
#           RND      ADMIN        MKT  STATE
# 46    1315.46  115816.21  297114.46      1
# 13   91992.39  135495.07  252664.93      0
# 2   153441.51  101145.55  407934.54      1
# 22   73994.56  122782.75  303319.26      1
# 15  114523.61  122616.84  261776.23      2
# 28   66051.52  182645.56  118148.20      1
# 23   67532.53  105751.03  304768.73      1
# 45    1000.23  124153.04    1903.93      2
# 14  119943.24  156547.42  256512.92      1
# 19   86419.70  153514.11       0.00      2
# 18   91749.16  114175.79  294919.57      1
# 17   94657.16  145077.58  282574.31      2
# 27   72107.60  127864.55  353183.81      2
# 48     542.05   51743.15       0.00      2
# 30   61994.48  115641.28   91131.24      1
# 12   93863.75  127320.38  249839.44      1
# 33   55493.95  103057.49  214634.81      1
# 35   46014.02   85047.44  205517.64      2
# 42   23640.93   96189.63  148001.11      0
# 24   77044.01   99281.34  140574.81      2
# 7   130298.13  145530.06  323876.68      1
# ...

# %%
km.fit_predict(x_test)
# Out:
# array([4, 0, 2, 3, 1])

# %%
labels = km.fit_predict(x)
labels

plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("UNclustered Data")
plt.scatter(df['RND'],df['PROFIT'])

plt.subplot(1,2,2)
plt.title("clustered Data")
plt.scatter(df['RND'],df['PROFIT'],c=labels)

centers = km.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],marker='x',color='red')
